# %%
##  OCR --> read characters from image

# %%
## for windows user only
path = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
#pip install pytesseract   ##   pytho module for tesseract

# %%
import pytesseract
from PIL import Image

# %%
## for windows user only
pytesseract.pytesseract.tesseract_cmd = path

# %%
img = Image.open('text.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x229 at 0x23CAA5D2970>

# %%
text=pytesseract.image_to_string(img)
text
# Out:
# 'This is the first line of\nthis text example.\n\nThis is the second line\nof the same text.\n\x0c'

# %%
text.split('\n')
# Out:
# ['This is the first line of',
#  'this text example.',
#  '',
#  'This is the second line',
#  'of the same text.',
#  '\x0c']

# %%
img2 = Image.open('text2.png')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x1174 at 0x23CAA5D2070>

# %%
img2 = Image.open('text2.png')
text2=pytesseract.image_to_string(img2)
text2
# Out:
# '® Texts\n\nOy ar=Blalerey.@\nPANIBY(o) 0] m=). 4ice\n\x0c'

# %%
text2.split('\n')
# Out:
# ['® Texts', '', 'Oy ar=Blalerey.@', 'PANIBY(o) 0] m=). 4ice', '\x0c']
