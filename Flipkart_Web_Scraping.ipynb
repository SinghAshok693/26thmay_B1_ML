# %%
import requests
from bs4 import BeautifulSoup

# %%
curr_page=1
product='smart phones'
url ='https://www.flipkart.com/search?q='

# %%
header={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
}

# %%
query_url=url+ '+'.join(product.split())+'&page={}'.format(curr_page)
query_url
# Out:
# 'https://www.flipkart.com/search?q=smart+phones&page=1'

# %%
r=requests.get(query_url,headers=header)
r.status_code
# Out:
# 200

# %%
text=r.text
soup=BeautifulSoup(text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
result_page=soup.find_all('div',{'class':'_1YokD2 _3Mn1Gg'})[1]

# %%
result_page
# Out:
# <div class="_1YokD2 _3Mn1Gg" style="flex-grow:1;overflow:auto"><div class="_1YokD2 _2GoDe3 col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="_1AtVbE" style="flex-grow:1;overflow:auto"><div class="W_R1IA"><div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">Mobiles &amp; Accessories</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">Mobiles</a><svg clas
# ...

# %%
titles=[i.text for i in result_page.find_all('div',{'class':'_4rR01T'})]

# %%
disc_price=[i.text for i in result_page.find_all('div',{'class':'_30jeq3 _1_WHN1'})]

# %%
avg_rating=[eval(i.text) for i in result_page.find_all('div',{'class':'_3LWZlK'})]

# %%
totals=[i.text.split('\xa0&\xa0') for i in result_page.find_all('span',{'class':'_2_R_DZ'})]
totals
# Out:
# [['3,17,243 Ratings', '17,994 Reviews'],
#  ['64,477 Ratings', '5,163 Reviews'],
#  ['64,477 Ratings', '5,163 Reviews'],
#  ['64,477 Ratings', '5,163 Reviews'],
#  ['64,477 Ratings', '5,163 Reviews'],
#  ['1,64,647 Ratings', '13,769 Reviews'],
#  ['1,64,647 Ratings', '13,769 Reviews'],
#  ['23,193 Ratings', '1,751 Reviews'],
#  ['41,458 Ratings', '3,426 Reviews'],
#  ['41,843 Ratings', '1,929 Reviews'],
#  ['41,843 Ratings', '1,929 Reviews'],
#  ['20,873 Ratings', '854 Reviews'],
#  ['21,923 Ratings', '977 Reviews'],
#  ['21,923 Ratings', '977 Reviews'],
#  ['1,64,647 Ratings', '13,769 Reviews'],
#  ['20,873 Ratings', '854 Reviews'],
#  ['47,914 Ratings', '3,525 Reviews'],
#  ['1,76,091 Ratings', '13,034 Reviews'],
#  ['76,334 Ratings', '4,822 Reviews'],
#  ['76,334 Ratings', '4,822 Reviews'],
#  ['49,743 Ratings', '3,521 Reviews'],
#  ['49,743 Ratings', '3,521 Reviews'],
#  ['23,193 Ratings', '1,751 Reviews'],
#  ['23,193 Ratings', '1,751 Reviews']]

# %%
len(disc_price)
# Out:
# 24

# %%
len(avg_rating)
# Out:
# 24

# %%
len(titles)
# Out:
# 24

# %%
import pandas as pd

# %%
df = pd.DataFrame({'title':titles, 'price':disc_price, 'avg_rating':avg_rating})
df.head()
# Out:
#                                     title   price  avg_rating
# 0        REDMI 9i (Midnight Black, 64 GB)  ₹8,299         4.3
# 1       Infinix Hot 10 (Amber Red, 64 GB)  ₹8,999         4.4
# 2  Infinix Hot 10 (Moonlight Jade, 64 GB)  ₹8,999         4.4
# 3      Infinix Hot 10 (Ocean Wave, 64 GB)  ₹8,999         4.4
# 4  Infinix Hot 10 (Obsidian Black, 64 GB)  ₹8,999         4.4
